# %% [markdown]
# <center>
#
#     COMP4240/5435 - Reinforcement Learning
#
# # Policy Control with Approximation
#
#
# </center>

# %% [markdown]
# **Author Student Name: Emmanuel Ndaliro**

# %% [markdown]
# **General Notes:**
# - Questions marked with * are optional for COMP4240 - Undergraduate section. Questions marked as extra credit are optional for everyone.
# - Do not use a mix of python lists and numpy arrays. Every vector or matrix in your code should be a numpy array.
# - For functions that exist in both the python core and the numpy library, use the one in the numpy library. For example, use `np.max` instead of `max`. Another example: use `np.random.normal` instead of `random.gauss`.
# - Make sure all of your plots have a proper size and include `xlabel`, `ylabel`, `legend`, `title`, and `grid`.

# %% [markdown]
# The purpose of this project is to study different properties of Function Approximation with on-policy control methods.

# %%
# You are allowed to use the following modules
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym

# %% [markdown]
# ## Task description
# Consider the task of driving an underpowered car up a steep mountain road, as suggested by the diagram in the upper left of the following figure. The difficulty is that gravity is stronger than the car's engine, and even at full throttle the car cannot accelerate up the steep slope. The only solution is to first move away from the goal and up the opposite slope on the left. Then by applying full throttle the car can build up enough inertia to carry it up the steep slope even though it is slowing down the whole way.
#
#
# ![mc.png](attachment:mc.png)
#
#
# This is a continuous control task where things have to get worse in a sense (farther from the goal) before they can get better.
#
# **Observation space**
#
# The observation is two dimensional including the position of the car along the x-axis and velocity of the car.
#
# **Action space**
#
# There are three deterministic actions: 0 accelerate to the left, 1 do nothing, and 2 accelerate to the right.
#
# **Transition dynamics**
#
# The car moves according to a simplified physics. Its position $x_t$ and velocity $\dot{x}_t$ are updated by
#
# $x_{t+1} \doteq \text{bound}[x_t + \dot{x}_{t+1}]$
#
# $\dot{x}_{t+1} \doteq \text{bound}[\dot{x}_t + 0.001 (A_t-1) - 0.0025 \cos(3x_t)]$
#
#
# where the \textit{bound} operation enforces $-1.2 \le x_{t+1} \le 0.6$ and $-0.07 \le \dot{x}_{t+1} \le 0.07$. In addition, when $x_{t+1}$ reached the left bound, $\dot{x}_{t+1}$ was reset to zero. When it reached the right bound, the goal was reached and the episode was terminated.
#
# **Reward**
#
# The reward in this problem is -1 on all time steps until the car moves past its goal position at the top of the mountain, which ends the episode.
#
# **Initial State**
#
# Each episode starts from a random position $x_t \in [-0.6, -0.4)$ and zero velocity.
#
# **Goal and Termination**
#
# The episode terminates when the position of the car is greater than or equal to 0.5 (the goal position on top of the right hill).
#
# **Arguments**
#
# > env = gym.make('MountainCar-v0')
#
# **Note**
#
# Do not use the Continuous Mountain Car environment for this homework.
# > gym.make('MountainCarContinuous-v0')

# %% [markdown]
# ## Part I (4 points)
#
# Check and confirm that the given Mountain Car simulation works as expected. Make sure you can observe and log (if needed) all the observations, actions, rewards, and termination conditions. You can animate the simulation by adding `render_mode='human'` when calling the `gym.make` class.

# %%
#--- Your code here ---

env = gym.make('MountainCar-v0')

# Confirming the environment by observing initial state
state = env.reset()
print(f'Initial State: {state}')

# Sample interaction with the environment
done = False
while not done:
    action = env.action_space.sample()  # Random action
    output = env.step(action)
    state, reward, done, _ = output[:4]  # Unpacking only the first four elements
    print(f'State: {state}, Reward: {reward}, Done: {done}')
    if done:
        break

env.close()
# Out:
# Initial State: (array([-0.55638784,  0.        ], dtype=float32), {})
# State: [-0.5551423   0.00124552], Reward: -1.0, Done: False
# State: [-5.5466056e-01  4.8174485e-04], Reward: -1.0, Done: False
# State: [-0.5539462   0.00071437], Reward: -1.0, Done: False
# State: [-5.5400449e-01 -5.8337664e-05], Reward: -1.0, Done: False
# State: [-0.5528351   0.00116939], Reward: -1.0, Done: False
# State: [-5.5244672e-01  3.8838087e-04], Reward: -1.0, Done: False
# State: [-0.5518423   0.00060447], Reward: -1.0, Done: False
# State: [-0.5510262   0.00081604], Reward: -1.0, Done: False
# State: [-0.5500047   0.00102152], Reward: -1.0, Done: False
# State: [-5.4978538e-01  2.1935483e-04], Reward: -1.0, Done: False
# State: [-0.5483698   0.00141555], Reward: -1.0, Done: False
# State: [-0.54776865  0.00060116], Reward: -1.0, Done: False
# State: [-5.479864e-01 -2.177208e-04], Reward: -1.0, Done: False
# State: [-0.5470213   0.00096502], Reward: -1.0, Done: False
# State: [-5.4688078e-01  1.4054768e-04], Reward: -1.0, Done: False
# State: [-0.5455658   0.00131502], Reward: -1.0, Done: False
# State: [-5.4508615e-01  4.7965409e-04], Reward: -1.0, Done: False
# State: [-5.4544544e-01 -3.5930244e-04], Reward: -1.0, Done: False
# State: [-0.544641    0.00080443], Reward: -1.0, Done: False
# State: [-5.4467887e-01 -3.7858073e-05], Reward: -1.0, Done: False
# State: [-0.5455587  -0.00087986], Reward: -1.0, Done: False
# State: [-0.546274   -0.00071528], Reward: -1.0, Done: False
# State: [-0.5478193  -0.00154535], Reward: -1.0, Done: False
# State: [-0.5501832  -0.00236386], Reward: -1.0, Done: False
# State: [-0.55134785 -0.00116468], Reward: -1.0, Done: False
# State: [-0.5523047  -0.00095681], Reward: -1.0, Done: False
# State: [-5.520465e-01  2.582231e-04], Reward: -1.0, Done: False
# State: [-0.55057514  0.00147132], Reward: -1.0, Done: False
# State: [-0.54890174  0.00167342], Reward: -1.0, Done: False
# State: [-0.5460387   0.00286301], Reward: -1.0, Done: False
# State: [-0.5420075   0.00403119], Reward: -1.0, Done: False
# State: [-0.5388383   0.00316918], Reward: -1.0, Done: False
# State: [-0.5365549   0.00228344], Reward: -1.0, Done: False
# State: [-0.53317434  0.00338058], Reward: -1.0, Done: False
# State: [-0.5297219   0.00345239], Reward: -1.0, Done: False
# State: [-0.5252236   0.00449831], Reward: -1.0, Done: False
# State: [-0.5197131  0.0055105], Reward: -1.0, Done: False
# State: [-0.5152317   0.00448136], Reward: -1.0, Done: False
# State: [-0.5108131   0.00441861], Reward: -1.0, Done: False
# State: [-0.5074904   0.00332274], Reward: -1.0, Done: False
# State: [-0.50328845  0.00420198], Reward: -1.0, Done: False
# State: [-0.49823868  0.00504974], Reward: -1.0, Done: False
# State: [-0.49437895  0.00385973], Reward: -1.0, Done: False
# State: [-0.4917381   0.00264086], Reward: -1.0, Done: False
# State: [-0.49033582  0.00140227], Reward: -1.0, Done: False
# State: [-4.9018264e-01  1.5320779e-04], Reward: -1.0, Done: False
# State: [-4.9027961e-01 -9.6993776e-05], Reward: -1.0, Done: False
# State: [-4.9062610e-01 -3.4647153e-04], Reward: -1.0, Done: False
# State: [-0.49221945 -0.00159336], Reward: -1.0, Done: False
# State: [-0.4930478  -0.00082836], Reward: -1.0, Done: False
# State: [-0.495105   -0.00205717], Reward: -1.0, Done: False
# State: [-0.4983756  -0.00327062], Reward: -1.0, Done: False
# State: [-0.5028352  -0.00445961], Reward: -1.0, Done: False
# State: [-0.5064505  -0.00361524], Reward: -1.0, Done: False
# State: [-0.51019424 -0.00374379], Reward: -1.0, Done: False
# State: [-0.51503855 -0.0048443 ], Reward: -1.0, Done: False
# State: [-0.52094704 -0.00590849], Reward: -1.0, Done: False
# State: [-0.5278754  -0.00692838], Reward: -1.0, Done: False
# State: [-0.5337717  -0.00589631], Reward: -1.0, Done: False
# State: [-0.5395917  -0.00582002], Reward: -1.0, Done: False
# State: [-0.54529184 -0.00570012], Reward: -1.0, Done: False
# State: [-0.5508294  -0.00553754], Reward: -1.0, Done: False
# State: [-0.55616295 -0.00533353], Reward: -1.0, Done: False
# State: [-0.5612526  -0.00508969], Reward: -1.0, Done: False
# State: [-0.5660605  -0.00480789], Reward: -1.0, Done: False
# State: [-0.5715508  -0.00549029], Reward: -1.0, Done: False
# State: [-0.5766827  -0.00513188], Reward: -1.0, Done: False
# State: [-0.5814181  -0.00473544], Reward: -1.0, Done: False
# State: [-0.5867221  -0.00530396], Reward: -1.0, Done: False
# State: [-0.5905554  -0.00383336], Reward: -1.0, Done: False
# State: [-0.59389    -0.00333456], Reward: -1.0, Done: False
# State: [-0.59670126 -0.00281127], Reward: -1.0, Done: False
# State: [-0.59796864 -0.00126739], Reward: -1.0, Done: False
# State: [-0.5986829  -0.00071423], Reward: -1.0, Done: False
# State: [-0.59783876  0.00084415], Reward: -1.0, Done: False
# State: [-5.9744239e-01  3.9635962e-04], Reward: -1.0, Done: False
# State: [-0.5954967   0.00194567], Reward: -1.0, Done: False
# State: [-0.59301597  0.00248073], Reward: -1.0, Done: False
# State: [-0.58901834  0.0039976 ], Reward: -1.0, Done: False
# State: [-0.5835333   0.00548511], Reward: -1.0, Done: False
# State: [-0.5776011  0.0059322], Reward: -1.0, Done: False
# State: [-0.5722656   0.00533545], Reward: -1.0, Done: False
# State: [-0.56756645  0.00469915], Reward: -1.0, Done: False
# State: [-0.5625385   0.00502795], Reward: -1.0, Done: False
# State: [-0.55721915  0.00531934], Reward: -1.0, Done: False
# State: [-0.5516481   0.00557106], Reward: -1.0, Done: False
# State: [-0.5468669   0.00478119], Reward: -1.0, Done: False
# State: [-0.5409114   0.00595556], Reward: -1.0, Done: False
# State: [-0.533826    0.00708534], Reward: -1.0, Done: False
# State: [-0.525664    0.00816203], Reward: -1.0, Done: False
# State: [-0.51748645  0.00817752], Reward: -1.0, Done: False
# State: [-0.50935477  0.00813168], Reward: -1.0, Done: False
# State: [-0.5023299   0.00702489], Reward: -1.0, Done: False
# State: [-0.49646443  0.00586548], Reward: -1.0, Done: False
# State: [-0.49180222  0.00466219], Reward: -1.0, Done: False
# State: [-0.48637813  0.00542408], Reward: -1.0, Done: False
# State: [-0.48123264  0.00514551], Reward: -1.0, Done: False
# State: [-0.476404    0.00482862], Reward: -1.0, Done: False
# State: [-0.47192818  0.00447584], Reward: -1.0, Done: False
# State: [-0.46683833  0.00508986], Reward: -1.0, Done: False
# State: [-0.46217212  0.00466621], Reward: -1.0, Done: False
# State: [-0.45896402  0.00320811], Reward: -1.0, Done: False
# State: [-0.45523763  0.00372638], Reward: -1.0, Done: False
# State: [-0.45202038  0.00321726], Reward: -1.0, Done: False
# State: [-0.44933584  0.00268454], Reward: -1.0, Done: False
# State: [-0.44820365  0.00113216], Reward: -1.0, Done: False
# State: [-0.44663215  0.00157151], Reward: -1.0, Done: False
# State: [-0.4446328   0.00199937], Reward: -1.0, Done: False
# State: [-0.44322014  0.00141265], Reward: -1.0, Done: False
# State: [-4.4340450e-01 -1.8436136e-04], Reward: -1.0, Done: False
# State: [-0.44518453 -0.00178003], Reward: -1.0, Done: False
# State: [-0.44654727 -0.00136273], Reward: -1.0, Done: False
# State: [-0.44848275 -0.00193548], Reward: -1.0, Done: False
# State: [-0.45097685 -0.0024941 ], Reward: -1.0, Done: False
# State: [-0.4540113  -0.00303446], Reward: -1.0, Done: False
# State: [-0.4575639  -0.00355259], Reward: -1.0, Done: False
# State: [-0.4606085  -0.00304462], Reward: -1.0, Done: False
# State: [-0.46412274 -0.00351424], Reward: -1.0, Done: False
# State: [-0.4680807  -0.00395794], Reward: -1.0, Done: False
# State: [-0.4724531  -0.00437241], Reward: -1.0, Done: False
# State: [-0.4782076 -0.0057545], Reward: -1.0, Done: False
# State: [-0.48430148 -0.00609388], Reward: -1.0, Done: False
# State: [-0.4896894  -0.00538793], Reward: -1.0, Done: False
# State: [-0.4943312  -0.00464181], Reward: -1.0, Done: False
# State: [-0.5001922  -0.00586103], Reward: -1.0, Done: False
# State: [-0.5052287  -0.00503644], Reward: -1.0, Done: False
# State: [-0.51140285 -0.00617414], Reward: -1.0, Done: False
# State: [-0.5176684  -0.00626559], Reward: -1.0, Done: False
# State: [-0.5229785  -0.00531007], Reward: -1.0, Done: False
# State: [-0.5272932  -0.00431472], Reward: -1.0, Done: False
# State: [-0.5325802  -0.00528701], Reward: -1.0, Done: False
# State: [-0.5367999  -0.00421966], Reward: -1.0, Done: False
# State: [-0.54192054 -0.00512068], Reward: -1.0, Done: False
# State: [-0.5469039  -0.00498333], Reward: -1.0, Done: False
# State: [-0.55271256 -0.00580869], Reward: -1.0, Done: False
# State: [-0.55930316 -0.00659061], Reward: -1.0, Done: False
# State: [-0.5646265  -0.00532334], Reward: -1.0, Done: False
# State: [-0.57064295 -0.00601641], Reward: -1.0, Done: False
# State: [-0.57530767 -0.00466475], Reward: -1.0, Done: False
# State: [-0.57858616 -0.00327848], Reward: -1.0, Done: False
# State: [-0.58245414 -0.00386795], Reward: -1.0, Done: False
# State: [-0.58588296 -0.00342882], Reward: -1.0, Done: False
# State: [-0.5898473 -0.0039644], Reward: -1.0, Done: False
# State: [-0.5923182 -0.0024708], Reward: -1.0, Done: False
# State: [-0.5952772  -0.00295905], Reward: -1.0, Done: False
# State: [-0.5967028 -0.0014256], Reward: -1.0, Done: False
# State: [-5.9658450e-01  1.1829841e-04], Reward: -1.0, Done: False
# State: [-5.9692317e-01 -3.3867205e-04], Reward: -1.0, Done: False
# State: [-0.59771633 -0.00079316], Reward: -1.0, Done: False
# State: [-0.5989582  -0.00124185], Reward: -1.0, Done: False
# State: [-0.60063964 -0.00168146], Reward: -1.0, Done: False
# State: [-6.00748420e-01 -1.08781656e-04], Reward: -1.0, Done: False
# State: [-0.59928375  0.00146469], Reward: -1.0, Done: False
# State: [-0.5972563   0.00202746], Reward: -1.0, Done: False
# State: [-0.59468085  0.00257541], Reward: -1.0, Done: False
# State: [-0.59057635  0.00410449], Reward: -1.0, Done: False
# State: [-0.5859729   0.00460345], Reward: -1.0, Done: False
# State: [-0.5819044   0.00406853], Reward: -1.0, Done: False
# State: [-0.5784008  0.0035036], Reward: -1.0, Done: False
# State: [-0.57348806  0.00491276], Reward: -1.0, Done: False
# State: [-0.5682025   0.00528554], Reward: -1.0, Done: False
# State: [-0.56158346  0.00661907], Reward: -1.0, Done: False
# State: [-0.5546801   0.00690334], Reward: -1.0, Done: False
# State: [-0.548544    0.00613611], Reward: -1.0, Done: False
# State: [-0.54122096  0.00732302], Reward: -1.0, Done: False
# State: [-0.53476584  0.00645513], Reward: -1.0, Done: False
# State: [-0.528227    0.00653887], Reward: -1.0, Done: False
# State: [-0.52065337  0.00757358], Reward: -1.0, Done: False
# State: [-0.5141019   0.00655149], Reward: -1.0, Done: False
# State: [-0.50862163  0.00548027], Reward: -1.0, Done: False
# State: [-0.50225365  0.00636798], Reward: -1.0, Done: False
# State: [-0.49704567  0.005208  ], Reward: -1.0, Done: False
# State: [-0.4920366   0.00500906], Reward: -1.0, Done: False
# State: [-0.4882639  0.0037727], Reward: -1.0, Done: False
# State: [-0.48475572  0.00350818], Reward: -1.0, Done: False
# State: [-0.4815382   0.00321752], Reward: -1.0, Done: False
# State: [-0.4776353  0.0039029], Reward: -1.0, Done: False
# State: [-0.47307605  0.00455927], Reward: -1.0, Done: False
# State: [-0.46989423  0.00318179], Reward: -1.0, Done: False
# State: [-0.46811348  0.00178075], Reward: -1.0, Done: False
# State: [-4.6774694e-01  3.6653050e-04], Reward: -1.0, Done: False
# State: [-0.46879736 -0.0010504 ], Reward: -1.0, Done: False
# State: [-4.6925691e-01 -4.5956246e-04], Reward: -1.0, Done: False
# State: [-0.47012225 -0.00086532], Reward: -1.0, Done: False
# State: [-4.7038692e-01 -2.6467920e-04], Reward: -1.0, Done: False
# State: [-0.472049   -0.00166208], Reward: -1.0, Done: False
# State: [-0.47509617 -0.00304716], Reward: -1.0, Done: False
# State: [-0.4775058  -0.00240965], Reward: -1.0, Done: False
# State: [-0.47926006 -0.00175424], Reward: -1.0, Done: False
# State: [-0.48134586 -0.0020858 ], Reward: -1.0, Done: False
# State: [-0.4827477  -0.00140185], Reward: -1.0, Done: False
# State: [-0.48345518 -0.00070747], Reward: -1.0, Done: False
# State: [-4.834630e-01 -7.819395e-06], Reward: -1.0, Done: False
# State: [-0.4847711  -0.00130811], Reward: -1.0, Done: False
# State: [-0.48736978 -0.00259866], Reward: -1.0, Done: False
# State: [-0.49023962 -0.00286984], Reward: -1.0, Done: False
# State: [-0.49235922 -0.00211962], Reward: -1.0, Done: False
# State: [-0.4957128  -0.00335357], Reward: -1.0, Done: False
# State: [-0.50027525 -0.00456247], Reward: -1.0, Done: False
# State: [-0.5050125  -0.00473726], Reward: -1.0, Done: False
# State: [-0.5098891  -0.00487658], Reward: -1.0, Done: False
# State: [-0.5148685  -0.00497938], Reward: -1.0, Done: False
# State: [-0.5189133  -0.00404485], Reward: -1.0, Done: False
# State: [-0.5229933  -0.00407999], Reward: -1.0, Done: False
# State: [-0.52607787 -0.00308453], Reward: -1.0, Done: False
# State: [-0.5291438  -0.00306593], Reward: -1.0, Done: False
# State: [-0.5311681  -0.00202435], Reward: -1.0, Done: False
# State: [-0.5331357  -0.00196758], Reward: -1.0, Done: False
# State: [-0.5360318  -0.00289607], Reward: -1.0, Done: False
# State: [-0.53783464 -0.00180284], Reward: -1.0, Done: False
# State: [-0.5395307 -0.0016961], Reward: -1.0, Done: False
# State: [-0.54010737 -0.00057666], Reward: -1.0, Done: False
# State: [-5.4056025e-01 -4.5289486e-04], Reward: -1.0, Done: False
# State: [-0.54188603 -0.00132574], Reward: -1.0, Done: False
# State: [-0.54407465 -0.00218865], Reward: -1.0, Done: False
# State: [-0.54710984 -0.00303518], Reward: -1.0, Done: False
# State: [-0.54996884 -0.00285899], Reward: -1.0, Done: False
# State: [-0.55263025 -0.00266142], Reward: -1.0, Done: False
# State: [-0.5540742  -0.00144396], Reward: -1.0, Done: False
# State: [-0.55629    -0.00221572], Reward: -1.0, Done: False
# State: [-0.5572609  -0.00097092], Reward: -1.0, Done: False
# State: [-5.5697978e-01  2.8111192e-04], Reward: -1.0, Done: False
# State: [-5.5744869e-01 -4.6894897e-04], Reward: -1.0, Done: False
# State: [-0.5566642   0.00078449], Reward: -1.0, Done: False
# State: [-0.5556321   0.00103207], Reward: -1.0, Done: False
# State: [-5.5536020e-01  2.7195425e-04], Reward: -1.0, Done: False
# State: [-5.5585039e-01 -4.9019547e-04], Reward: -1.0, Done: False
# State: [-5.5609906e-01 -2.4868562e-04], Reward: -1.0, Done: False
# State: [-5.5610436e-01 -5.3194535e-06], Reward: -1.0, Done: False
# State: [-5.5586630e-01  2.3808643e-04], Reward: -1.0, Done: False
# State: [-5.563866e-01 -5.202849e-04], Reward: -1.0, Done: False
# State: [-0.5556614   0.00072523], Reward: -1.0, Done: False
# State: [-5.5569601e-01 -3.4673965e-05], Reward: -1.0, Done: False
# State: [-5.5549037e-01  2.0568362e-04], Reward: -1.0, Done: False
# State: [-5.5604583e-01 -5.5549433e-04], Reward: -1.0, Done: False
# State: [-0.5573584  -0.00131253], Reward: -1.0, Done: False
# State: [-5.5741811e-01 -5.9761132e-05], Reward: -1.0, Done: False
# State: [-0.5582247  -0.00080655], Reward: -1.0, Done: False
# State: [-0.559772   -0.00154732], Reward: -1.0, Done: False
# State: [-5.6004858e-01 -2.7655638e-04], Reward: -1.0, Done: False
# State: [-0.5590523   0.00099627], Reward: -1.0, Done: False
# State: [-0.55779064  0.00126167], Reward: -1.0, Done: False
# State: [-5.5727297e-01  5.1766215e-04], Reward: -1.0, Done: False
# State: [-0.5565032   0.00076979], Reward: -1.0, Done: False
# State: [-0.554487    0.00201617], Reward: -1.0, Done: False
# State: [-0.5512395  0.0032475], Reward: -1.0, Done: False
# State: [-0.5477849   0.00345457], Reward: -1.0, Done: False
# State: [-0.5441491   0.00363581], Reward: -1.0, Done: False
# State: [-0.54035926  0.00378984], Reward: -1.0, Done: False
# State: [-0.5374438   0.00291549], Reward: -1.0, Done: False
# State: [-0.5334245   0.00401929], Reward: -1.0, Done: False
# State: [-0.5303315   0.00309298], Reward: -1.0, Done: False
# State: [-0.52818805  0.00214347], Reward: -1.0, Done: False
# State: [-0.52601016  0.00217789], Reward: -1.0, Done: False
# State: [-0.5238142   0.00219597], Reward: -1.0, Done: False
# State: [-0.5206166   0.00319759], Reward: -1.0, Done: False
# State: [-0.5174414   0.00317522], Reward: -1.0, Done: False
# State: [-0.51331234  0.00412904], Reward: -1.0, Done: False
# State: [-0.5102604   0.00305191], Reward: -1.0, Done: False
# State: [-0.50630856  0.0039519 ], Reward: -1.0, Done: False
# State: [-0.50148624  0.00482228], Reward: -1.0, Done: False
# State: [-0.4968297   0.00465656], Reward: -1.0, Done: False
# State: [-0.49237368  0.004456  ], Reward: -1.0, Done: False
# State: [-0.48715153  0.00522216], Reward: -1.0, Done: False
# State: [-0.4832022   0.00394935], Reward: -1.0, Done: False
# State: [-0.48055506  0.00264712], Reward: -1.0, Done: False
# State: [-0.47822988  0.00232518], Reward: -1.0, Done: False
# State: [-0.4762439   0.00198597], Reward: -1.0, Done: False
# State: [-0.4746119  0.001632 ], Reward: -1.0, Done: False
# State: [-4.7434601e-01  2.6591815e-04], Reward: -1.0, Done: False
# State: [-0.47344813  0.00089786], Reward: -1.0, Done: False
# State: [-0.473925   -0.00047685], Reward: -1.0, Done: False
# State: [-4.7377300e-01  1.5197645e-04], Reward: -1.0, Done: False
# State: [-4.7399333e-01 -2.2032679e-04], Reward: -1.0, Done: False
# State: [-0.4745843 -0.000591 ], Reward: -1.0, Done: False
# State: [-4.745416e-01  4.271898e-05], Reward: -1.0, Done: False
# State: [-0.47386548  0.00067612], Reward: -1.0, Done: False
# State: [-4.7356099e-01  3.0449964e-04], Reward: -1.0, Done: False
# State: [-0.47463036 -0.00106938], Reward: -1.0, Done: False
# State: [-4.7506568e-01 -4.3531938e-04], Reward: -1.0, Done: False
# State: [-0.4768637  -0.00179803], Reward: -1.0, Done: False
# State: [-0.47901112 -0.0021474 ], Reward: -1.0, Done: False
# State: [-0.48249194 -0.00348081], Reward: -1.0, Done: False
# State: [-0.48728025 -0.00478833], Reward: -1.0, Done: False
# State: [-0.49234045 -0.00506018], Reward: -1.0, Done: False
# State: [-0.4976347  -0.00529427], Reward: -1.0, Done: False
# State: [-0.5031235  -0.00548881], Reward: -1.0, Done: False
# State: [-0.50776577 -0.00464228], Reward: -1.0, Done: False
# State: [-0.51152676 -0.00376098], Reward: -1.0, Done: False
# State: [-0.51437825 -0.0028515 ], Reward: -1.0, Done: False
# State: [-0.51729894 -0.00292064], Reward: -1.0, Done: False
# State: [-0.52026683 -0.00296789], Reward: -1.0, Done: False
# State: [-0.5222597  -0.00199288], Reward: -1.0, Done: False
# State: [-0.5232626  -0.00100292], Reward: -1.0, Done: False
# State: [-0.52426803 -0.00100544], Reward: -1.0, Done: False
# State: [-0.5252685  -0.00100042], Reward: -1.0, Done: False
# State: [-5.2525640e-01  1.2098553e-05], Reward: -1.0, Done: False
# State: [-5.2523184e-01  2.4530525e-05], Reward: -1.0, Done: False
# State: [-0.52619505 -0.00096322], Reward: -1.0, Done: False
# State: [-5.2613884e-01  5.6250527e-05], Reward: -1.0, Done: False
# State: [-5.260635e-01  7.530067e-05], Reward: -1.0, Done: False
# State: [-0.52696973 -0.00090621], Reward: -1.0, Done: False
# State: [-0.5288507  -0.00188093], Reward: -1.0, Done: False
# State: [-0.5316922  -0.00284154], Reward: -1.0, Done: False
# State: [-0.53547305 -0.00378085], Reward: -1.0, Done: False
# State: [-0.5401649  -0.00469181], Reward: -1.0, Done: False
# State: [-0.5447325  -0.00456762], Reward: -1.0, Done: False
# State: [-0.5491417  -0.00440922], Reward: -1.0, Done: False
# State: [-0.55335957 -0.00421784], Reward: -1.0, Done: False
# State: [-0.55635446 -0.00299493], Reward: -1.0, Done: False
# State: [-0.56010413 -0.00374965], Reward: -1.0, Done: False
# State: [-0.56458056 -0.00447641], Reward: -1.0, Done: False
# State: [-0.5687504  -0.00416982], Reward: -1.0, Done: False
# State: [-0.5725826  -0.00383222], Reward: -1.0, Done: False
# State: [-0.57604873 -0.00346616], Reward: -1.0, Done: False
# State: [-0.5801231  -0.00407441], Reward: -1.0, Done: False
# State: [-0.5847756 -0.0046525], Reward: -1.0, Done: False
# State: [-0.5899719  -0.00519625], Reward: -1.0, Done: False
# State: [-0.5956736  -0.00570173], Reward: -1.0, Done: False
# State: [-0.59983903 -0.00416537], Reward: -1.0, Done: False
# State: [-0.60443753 -0.00459854], Reward: -1.0, Done: False
# State: [-0.60843575 -0.00399818], Reward: -1.0, Done: False
# State: [-0.6108045  -0.00236875], Reward: -1.0, Done: False
# State: [-0.6125266  -0.00172214], Reward: -1.0, Done: False
# State: [-0.6145897  -0.00206307], Reward: -1.0, Done: False
# State: [-6.1497879e-01 -3.8907872e-04], Reward: -1.0, Done: False
# State: [-0.61369103  0.00128772], Reward: -1.0, Done: False
# State: [-0.6127358   0.00095521], Reward: -1.0, Done: False
# State: [-0.61012006  0.0026158 ], Reward: -1.0, Done: False
# State: [-0.6078626   0.00225745], Reward: -1.0, Done: False
# State: [-0.60597986  0.00188272], Reward: -1.0, Done: False
# State: [-0.6044856   0.00149431], Reward: -1.0, Done: False
# State: [-0.60139054  0.00309502], Reward: -1.0, Done: False
# State: [-0.59671736  0.00467318], Reward: -1.0, Done: False
# State: [-0.59150016  0.00521718], Reward: -1.0, Done: False
# State: [-0.5857772   0.00572293], Reward: -1.0, Done: False
# State: [-0.58059067  0.00518657], Reward: -1.0, Done: False
# State: [-0.57497877  0.00561192], Reward: -1.0, Done: False
# State: [-0.568983    0.00599575], Reward: -1.0, Done: False
# State: [-0.56264794  0.00633508], Reward: -1.0, Done: False
# State: [-0.5560206   0.00662728], Reward: -1.0, Done: False
# State: [-0.5501506   0.00587006], Reward: -1.0, Done: False
# State: [-0.5450816   0.00506899], Reward: -1.0, Done: False
# State: [-0.5388516  0.00623  ], Reward: -1.0, Done: False
# State: [-0.5335072   0.00534436], Reward: -1.0, Done: False
# State: [-0.52808857  0.00541866], Reward: -1.0, Done: False
# State: [-0.52163625  0.00645233], Reward: -1.0, Done: False
# State: [-0.51519865  0.00643761], Reward: -1.0, Done: False
# State: [-0.507824    0.00737462], Reward: -1.0, Done: False
# State: [-0.49956766  0.00825635], Reward: -1.0, Done: False
# State: [-0.4904914   0.00907627], Reward: -1.0, Done: False
# State: [-0.48066303  0.00982838], Reward: -1.0, Done: False
# State: [-0.47115576  0.00950725], Reward: -1.0, Done: False
# State: [-0.46204022  0.00911555], Reward: -1.0, Done: False
# State: [-0.45438376  0.00765648], Reward: -1.0, Done: False
# State: [-0.44824266  0.00614109], Reward: -1.0, Done: False
# State: [-0.44366196  0.00458072], Reward: -1.0, Done: False
# State: [-0.44067502  0.00298692], Reward: -1.0, Done: False
# State: [-0.43730363  0.00337139], Reward: -1.0, Done: False
# State: [-0.43557227  0.00173138], Reward: -1.0, Done: False
# State: [-4.3549344e-01  7.8827223e-05], Reward: -1.0, Done: False
# State: [-4.3506771e-01  4.2570443e-04], Reward: -1.0, Done: False
# State: [-0.43629822 -0.0012305 ], Reward: -1.0, Done: False
# State: [-0.43917602 -0.00287779], Reward: -1.0, Done: False
# State: [-0.44268024 -0.00350422], Reward: -1.0, Done: False
# State: [-0.4467854  -0.00410516], Reward: -1.0, Done: False
# State: [-0.45246157 -0.00567618], Reward: -1.0, Done: False
# State: [-0.45966724 -0.00720567], Reward: -1.0, Done: False
# State: [-0.46834946 -0.00868222], Reward: -1.0, Done: False
# State: [-0.47844416 -0.01009469], Reward: -1.0, Done: False
# State: [-0.48787647 -0.00943232], Reward: -1.0, Done: False
# State: [-0.4965762  -0.00869972], Reward: -1.0, Done: False
# State: [-0.50647837 -0.00990217], Reward: -1.0, Done: False
# State: [-0.5155089  -0.00903052], Reward: -1.0, Done: False
# State: [-0.5256001  -0.01009119], Reward: -1.0, Done: False
# State: [-0.5366762  -0.01107618], Reward: -1.0, Done: False
# State: [-0.5476544  -0.01097812], Reward: -1.0, Done: False
# State: [-0.55945224 -0.01179786], Reward: -1.0, Done: False
# State: [-0.5699817  -0.01052948], Reward: -1.0, Done: False
# State: [-0.5811644  -0.01118273], Reward: -1.0, Done: False
# State: [-0.59291756 -0.01175313], Reward: -1.0, Done: False
# State: [-0.6051545  -0.01223698], Reward: -1.0, Done: False
# State: [-0.61678594 -0.01163139], Reward: -1.0, Done: False
# State: [-0.62672746 -0.00994156], Reward: -1.0, Done: False
# State: [-0.6359078  -0.00918037], Reward: -1.0, Done: False
# State: [-0.64326173 -0.0073539 ], Reward: -1.0, Done: False
# State: [-0.6487373  -0.00547558], Reward: -1.0, Done: False
# State: [-0.6532963  -0.00455893], Reward: -1.0, Done: False
# State: [-0.65790683 -0.00461056], Reward: -1.0, Done: False
# State: [-0.6605371  -0.00263028], Reward: -1.0, Done: False
# State: [-0.663169   -0.00263189], Reward: -1.0, Done: False
# State: [-0.6657844  -0.00261544], Reward: -1.0, Done: False
# State: [-6.6636550e-01 -5.8108877e-04], Reward: -1.0, Done: False
# State: [-6.669083e-01 -5.427758e-04], Reward: -1.0, Done: False
# State: [-6.6740906e-01 -5.0076103e-04], Reward: -1.0, Done: False
# State: [-6.668644e-01  5.446664e-04], Reward: -1.0, Done: False
# State: [-6.662780e-01  5.863818e-04], Reward: -1.0, Done: False
# State: [-6.6565394e-01  6.2409771e-04], Reward: -1.0, Done: False
# State: [-0.66299635  0.00265755], Reward: -1.0, Done: False
# State: [-0.66032356  0.00267283], Reward: -1.0, Done: False
# State: [-0.65665376  0.00366975], Reward: -1.0, Done: False
# State: [-0.6510124   0.00564137], Reward: -1.0, Done: False
# State: [-0.64543855  0.00557387], Reward: -1.0, Done: False
# State: [-0.6379711   0.00746746], Reward: -1.0, Done: False
# State: [-0.6296626   0.00830852], Reward: -1.0, Done: False
# State: [-0.6195719   0.01009064], Reward: -1.0, Done: False
# State: [-0.6097714   0.00980054], Reward: -1.0, Done: False
# State: [-0.59833175  0.01143966], Reward: -1.0, Done: False
# State: [-0.58633626  0.01199547], Reward: -1.0, Done: False
# State: [-0.57487303  0.01146323], Reward: -1.0, Done: False
# State: [-0.56202674  0.01284627], Reward: -1.0, Done: False
# State: [-0.5478929   0.01413384], Reward: -1.0, Done: False
# State: [-0.533577    0.01431589], Reward: -1.0, Done: False
# State: [-0.5201863   0.01339071], Reward: -1.0, Done: False
# State: [-0.50582117  0.01436512], Reward: -1.0, Done: False
# State: [-0.49158934  0.01423185], Reward: -1.0, Done: False
# State: [-0.4765972   0.01499215], Reward: -1.0, Done: False
# State: [-0.46295637  0.0136408 ], Reward: -1.0, Done: False
# State: [-0.4487679   0.01418849], Reward: -1.0, Done: False
# State: [-0.4341359   0.01463196], Reward: -1.0, Done: False
# State: [-0.4201669   0.01396902], Reward: -1.0, Done: False
# State: [-0.40696123  0.01320567], Reward: -1.0, Done: False
# State: [-0.39561263  0.01134863], Reward: -1.0, Done: False
# State: [-0.38520047  0.01041214], Reward: -1.0, Done: False
# State: [-0.37679675  0.00840372], Reward: -1.0, Done: False
# State: [-0.37045878  0.00633796], Reward: -1.0, Done: False
# State: [-0.3652294   0.00522938], Reward: -1.0, Done: False
# State: [-0.36114362  0.0040858 ], Reward: -1.0, Done: False
# State: [-0.35722855  0.00391505], Reward: -1.0, Done: False
# State: [-0.35551012  0.00171844], Reward: -1.0, Done: False
# State: [-0.3559996  -0.00048948], Reward: -1.0, Done: False
# State: [-0.35869378 -0.00269417], Reward: -1.0, Done: False
# State: [-0.3635749  -0.00488112], Reward: -1.0, Done: False
# State: [-0.36861062 -0.00503573], Reward: -1.0, Done: False
# State: [-0.37476733 -0.00615671], Reward: -1.0, Done: False
# State: [-0.38100356 -0.00623622], Reward: -1.0, Done: False
# State: [-0.38827693 -0.00727337], Reward: -1.0, Done: False
# State: [-0.39653757 -0.00826063], Reward: -1.0, Done: False
# State: [-0.40672824 -0.01019068], Reward: -1.0, Done: False
# State: [-0.4167776  -0.01004936], Reward: -1.0, Done: False
# State: [-0.4266145  -0.00983688], Reward: -1.0, Done: False
# State: [-0.43816853 -0.01155404], Reward: -1.0, Done: False
# State: [-0.4513563  -0.01318778], Reward: -1.0, Done: False
# State: [-0.46608165 -0.01472536], Reward: -1.0, Done: False
# State: [-0.48023626 -0.0141546 ], Reward: -1.0, Done: False
# State: [-0.49571517 -0.01547891], Reward: -1.0, Done: False
# State: [-0.510403   -0.01468779], Reward: -1.0, Done: False
# State: [-0.5261897  -0.01578673], Reward: -1.0, Done: False
# State: [-0.542957  -0.0167673], Reward: -1.0, Done: False
# State: [-0.5595792 -0.0166222], Reward: -1.0, Done: False
# State: [-0.5769321  -0.01735287], Reward: -1.0, Done: False
# State: [-0.5928866  -0.01595457], Reward: -1.0, Done: False
# State: [-0.6093253  -0.01643865], Reward: -1.0, Done: False
# State: [-0.626128   -0.01680276], Reward: -1.0, Done: False
# State: [-0.6411739  -0.01504586], Reward: -1.0, Done: False
# State: [-0.6553561  -0.01418222], Reward: -1.0, Done: False
# State: [-0.6695757  -0.01421957], Reward: -1.0, Done: False
# State: [-0.6837351 -0.0141594], Reward: -1.0, Done: False
# State: [-0.69673914 -0.01300405], Reward: -1.0, Done: False
# State: [-0.70850223 -0.01176311], Reward: -1.0, Done: False
# State: [-0.7179486  -0.00944636], Reward: -1.0, Done: False
# State: [-0.72501856 -0.00706993], Reward: -1.0, Done: False
# State: [-0.73066807 -0.00564955], Reward: -1.0, Done: False
# State: [-0.7338626  -0.00319451], Reward: -1.0, Done: False
# State: [-7.3458266e-01 -7.2004617e-04], Reward: -1.0, Done: False
# State: [-0.73282385  0.00175877], Reward: -1.0, Done: False
# State: [-0.7295969   0.00322693], Reward: -1.0, Done: False
# State: [-0.7259215   0.00367544], Reward: -1.0, Done: False
# State: [-0.7198201   0.00610139], Reward: -1.0, Done: False
# State: [-0.7133306   0.00648951], Reward: -1.0, Done: False
# State: [-0.7054937  0.0078369], Reward: -1.0, Done: False
# State: [-0.6963593   0.00913441], Reward: -1.0, Done: False
# State: [-0.6869864   0.00937288], Reward: -1.0, Done: False
# State: [-0.6754366  0.0115498], Reward: -1.0, Done: False
# State: [-0.661787    0.01364961], Reward: -1.0, Done: False
# State: [-0.6461304   0.01565659], Reward: -1.0, Done: False
# State: [-0.6295754   0.01655502], Reward: -1.0, Done: False
# State: [-0.6132389   0.01633652], Reward: -1.0, Done: False
# State: [-0.5972381   0.01600075], Reward: -1.0, Done: False
# State: [-0.58068955  0.01654856], Reward: -1.0, Done: False
# State: [-0.5637149   0.01697465], Reward: -1.0, Done: False
# State: [-0.5454401  0.0182748], Reward: -1.0, Done: False
# State: [-0.5270016   0.01843849], Reward: -1.0, Done: False
# State: [-0.5095376   0.01746401], Reward: -1.0, Done: False
# State: [-0.492179    0.01735858], Reward: -1.0, Done: False
# State: [-0.47505572  0.01712329], Reward: -1.0, Done: False
# State: [-0.45929524  0.0157605 ], Reward: -1.0, Done: False
# State: [-0.444014    0.01528121], Reward: -1.0, Done: False
# State: [-0.42932406  0.01468998], Reward: -1.0, Done: False
# State: [-0.41433173  0.0149923 ], Reward: -1.0, Done: False
# State: [-0.39914435  0.0151874 ], Reward: -1.0, Done: False
# State: [-0.38586882  0.01327553], Reward: -1.0, Done: False
# State: [-0.37359712  0.01227169], Reward: -1.0, Done: False
# State: [-0.36241284  0.01118427], Reward: -1.0, Done: False
# State: [-0.35239092  0.01002194], Reward: -1.0, Done: False
# State: [-0.3425973  0.0097936], Reward: -1.0, Done: False
# State: [-0.3350955   0.00750182], Reward: -1.0, Done: False
# State: [-0.3289333   0.00616221], Reward: -1.0, Done: False
# State: [-0.3231495  0.0057838], Reward: -1.0, Done: False
# State: [-0.31778008  0.00536941], Reward: -1.0, Done: False
# State: [-0.31485808  0.00292201], Reward: -1.0, Done: False
# State: [-0.31340128  0.00145679], Reward: -1.0, Done: False
# State: [-0.31441855 -0.00101727], Reward: -1.0, Done: False
# State: [-0.3169037  -0.00248516], Reward: -1.0, Done: False
# State: [-0.31984162 -0.00293792], Reward: -1.0, Done: False
# State: [-0.32321432 -0.0033727 ], Reward: -1.0, Done: False
# State: [-0.329001   -0.00578668], Reward: -1.0, Done: False
# State: [-0.33516568 -0.00616466], Reward: -1.0, Done: False
# State: [-0.3416695  -0.00650383], Reward: -1.0, Done: False
# State: [-0.35047108 -0.00880156], Reward: -1.0, Done: False
# State: [-0.3615135  -0.01104242], Reward: -1.0, Done: False
# State: [-0.3747242  -0.01321072], Reward: -1.0, Done: False
# State: [-0.39001474 -0.01529053], Reward: -1.0, Done: False
# State: [-0.40628055 -0.01626581], Reward: -1.0, Done: False
# State: [-0.4244082  -0.01812764], Reward: -1.0, Done: False
# State: [-0.44426882 -0.01986064], Reward: -1.0, Done: False
# State: [-0.46371883 -0.01945001], Reward: -1.0, Done: False
# State: [-0.48461553 -0.0208967 ], Reward: -1.0, Done: False
# State: [-0.50680393 -0.02218841], Reward: -1.0, Done: False
# State: [-0.5301183  -0.02331432], Reward: -1.0, Done: False
# State: [-0.5523837  -0.02226542], Reward: -1.0, Done: False
# State: [-0.5744335  -0.02204981], Reward: -1.0, Done: False
# State: [-0.59610355 -0.02167002], Reward: -1.0, Done: False
# State: [-0.61723405 -0.02113051], Reward: -1.0, Done: False
# State: [-0.63867146 -0.02143745], Reward: -1.0, Done: False
# State: [-0.6582629  -0.01959144], Reward: -1.0, Done: False
# State: [-0.6758716  -0.01760871], Reward: -1.0, Done: False
# State: [-0.6923776  -0.01650597], Reward: -1.0, Done: False
# State: [-0.70767117 -0.01529353], Reward: -1.0, Done: False
# State: [-0.7226532  -0.01498209], Reward: -1.0, Done: False
# State: [-0.7362296  -0.01357634], Reward: -1.0, Done: False
# State: [-0.74931717 -0.01308759], Reward: -1.0, Done: False
# State: [-0.7618383  -0.01252114], Reward: -1.0, Done: False
# State: [-0.7737209  -0.01188263], Reward: -1.0, Done: False
# State: [-0.7828988  -0.00917786], Reward: -1.0, Done: False
# State: [-0.7893222 -0.0064234], Reward: -1.0, Done: False
# State: [-0.7939571  -0.00463494], Reward: -1.0, Done: False
# State: [-0.7977795  -0.00382237], Reward: -1.0, Done: False
# State: [-0.7997697  -0.00199018], Reward: -1.0, Done: False
# State: [-0.80091757 -0.00114786], Reward: -1.0, Done: False
# State: [-8.0121726e-01 -2.9973601e-04], Reward: -1.0, Done: False
# State: [-0.79966736  0.0015499 ], Reward: -1.0, Done: False
# State: [-0.7952757  0.0043917], Reward: -1.0, Done: False
# State: [-0.7890646   0.00621107], Reward: -1.0, Done: False
# State: [-0.78006643  0.00899817], Reward: -1.0, Done: False
# State: [-0.770329    0.00973744], Reward: -1.0, Done: False
# State: [-0.7589055   0.01142351], Reward: -1.0, Done: False
# State: [-0.74686015  0.01204535], Reward: -1.0, Done: False
# State: [-0.73426276  0.01259739], Reward: -1.0, Done: False
# State: [-0.7201885   0.01407427], Reward: -1.0, Done: False
# State: [-0.7057238   0.01446469], Reward: -1.0, Done: False
# State: [-0.68896013  0.01676368], Reward: -1.0, Done: False
# State: [-0.6710065   0.01795364], Reward: -1.0, Done: False
# State: [-0.65198296  0.01902351], Reward: -1.0, Done: False
# State: [-0.6330202   0.01896277], Reward: -1.0, Done: False
# State: [-0.61425143  0.01876877], Reward: -1.0, Done: False
# State: [-0.5938111   0.02044031], Reward: -1.0, Done: False
# State: [-0.5728481   0.02096302], Reward: -1.0, Done: False
# State: [-0.55251706  0.02033105], Reward: -1.0, Done: False
# State: [-0.53196937  0.02054766], Reward: -1.0, Done: False
# State: [-0.51235896  0.01961043], Reward: -1.0, Done: False
# State: [-0.4918328   0.02052615], Reward: -1.0, Done: False
# State: [-0.47254455  0.01928827], Reward: -1.0, Done: False
# State: [-0.45263767  0.01990686], Reward: -1.0, Done: False
# State: [-0.43425903  0.01837866], Reward: -1.0, Done: False
# State: [-0.41554242  0.0187166 ], Reward: -1.0, Done: False
# State: [-0.3976221  0.0179203], Reward: -1.0, Done: False
# State: [-0.3796243   0.01799781], Reward: -1.0, Done: False
# State: [-0.36367306  0.01595126], Reward: -1.0, Done: False
# State: [-0.34987575  0.01379731], Reward: -1.0, Done: False
# State: [-0.33732316  0.01255257], Reward: -1.0, Done: False
# State: [-0.3260961   0.01122709], Reward: -1.0, Done: False
# State: [-0.3172651   0.00883098], Reward: -1.0, Done: False
# State: [-0.30988467  0.00738043], Reward: -1.0, Done: False
# State: [-0.3039995   0.00588515], Reward: -1.0, Done: False
# State: [-0.29864478  0.00535473], Reward: -1.0, Done: False
# State: [-0.29385203  0.00479276], Reward: -1.0, Done: False
# State: [-0.29164913  0.00220288], Reward: -1.0, Done: False
# State: [-0.29204884 -0.00039971], Reward: -1.0, Done: False
# State: [-0.29504886 -0.003     ], Reward: -1.0, Done: False
# State: [-0.2996318  -0.00458294], Reward: -1.0, Done: False
# State: [-0.3057709  -0.00613913], Reward: -1.0, Done: False
# State: [-0.31242993 -0.00665902], Reward: -1.0, Done: False
# State: [-0.3215689  -0.00913895], Reward: -1.0, Done: False
# State: [-0.333132  -0.0115631], Reward: -1.0, Done: False
# State: [-0.34704712 -0.01391513], Reward: -1.0, Done: False
# State: [-0.36222532 -0.01517821], Reward: -1.0, Done: False
# State: [-0.37956712 -0.01734179], Reward: -1.0, Done: False
# State: [-0.39695585 -0.01738873], Reward: -1.0, Done: False
# State: [-0.4152717  -0.01831586], Reward: -1.0, Done: False
# State: [-0.4353858  -0.02011409], Reward: -1.0, Done: False
# State: [-0.45615378 -0.02076799], Reward: -1.0, Done: False
# State: [-0.47742417 -0.02127038], Reward: -1.0, Done: False
# State: [-0.49903977 -0.02161559], Reward: -1.0, Done: False
# State: [-0.5218394  -0.02279961], Reward: -1.0, Done: False
# State: [-0.5436522  -0.02181281], Reward: -1.0, Done: False
# State: [-0.56431466 -0.0206625 ], Reward: -1.0, Done: False
# State: [-0.5846726  -0.02035789], Reward: -1.0, Done: False
# State: [-0.60557497 -0.02090239], Reward: -1.0, Done: False
# State: [-0.6248687  -0.01929375], Reward: -1.0, Done: False
# State: [-0.64341456 -0.01854586], Reward: -1.0, Done: False
# State: [-0.660081   -0.01666646], Reward: -1.0, Done: False
# State: [-0.67475224 -0.01467121], Reward: -1.0, Done: False
# State: [-0.68932825 -0.01457601], Reward: -1.0, Done: False
# State: [-0.7027119  -0.01338362], Reward: -1.0, Done: False
# State: [-0.71581584 -0.01310399], Reward: -1.0, Done: False
# State: [-0.7265568  -0.01074094], Reward: -1.0, Done: False
# State: [-0.7348679  -0.00831108], Reward: -1.0, Done: False
# State: [-0.7406984  -0.00583054], Reward: -1.0, Done: False
# State: [-0.7450134  -0.00431499], Reward: -1.0, Done: False
# State: [-0.7487872  -0.00377383], Reward: -1.0, Done: False
# State: [-0.7509977  -0.00221048], Reward: -1.0, Done: False
# State: [-7.5063193e-01  3.6576678e-04], Reward: -1.0, Done: False
# State: [-0.7496921   0.00093989], Reward: -1.0, Done: False
# State: [-0.7461836   0.00350852], Reward: -1.0, Done: False
# State: [-0.74212694  0.00405658], Reward: -1.0, Done: False
# State: [-0.73654634  0.00558064], Reward: -1.0, Done: False
# State: [-0.730475    0.00607131], Reward: -1.0, Done: False
# State: [-0.72394985  0.00652517], Reward: -1.0, Done: False
# State: [-0.7150109   0.00893895], Reward: -1.0, Done: False
# State: [-0.7057139   0.00929694], Reward: -1.0, Done: False
# State: [-0.6941181   0.01159586], Reward: -1.0, Done: False
# State: [-0.6822984  0.0118197], Reward: -1.0, Done: False
# State: [-0.6703329   0.01196549], Reward: -1.0, Done: False
# State: [-0.65730214  0.01303079], Reward: -1.0, Done: False
# State: [-0.6442952   0.01300689], Reward: -1.0, Done: False
# State: [-0.6314028   0.01289247], Reward: -1.0, Done: False
# State: [-0.6167158   0.01468697], Reward: -1.0, Done: False
# State: [-0.6003395   0.01637631], Reward: -1.0, Done: False
# State: [-0.5823927   0.01794679], Reward: -1.0, Done: False
# State: [-0.5650072   0.01738546], Reward: -1.0, Done: False
# State: [-0.548312    0.01669523], Reward: -1.0, Done: False
# State: [-0.5324316   0.01588041], Reward: -1.0, Done: False
# State: [-0.516485    0.01594664], Reward: -1.0, Done: False
# State: [-0.50059164  0.01589329], Reward: -1.0, Done: False
# State: [-0.4848708   0.01572088], Reward: -1.0, Done: False
# State: [-0.46943972  0.01543107], Reward: -1.0, Done: False
# State: [-0.45441306  0.01502666], Reward: -1.0, Done: False
# State: [-0.43890157  0.01551149], Reward: -1.0, Done: False
# State: [-0.4250185   0.01388307], Reward: -1.0, Done: False
# State: [-0.41086406  0.01415445], Reward: -1.0, Done: False
# State: [-0.39853907  0.01232497], Reward: -1.0, Done: False
# State: [-0.3871302   0.01140887], Reward: -1.0, Done: False
# State: [-0.3767165   0.01041371], Reward: -1.0, Done: False
# State: [-0.36736912  0.0093474 ], Reward: -1.0, Done: False
# State: [-0.358151   0.0092181], Reward: -1.0, Done: False
# State: [-0.35112342  0.00702757], Reward: -1.0, Done: False
# State: [-0.34433246  0.00679096], Reward: -1.0, Done: False
# State: [-0.33882213  0.00551034], Reward: -1.0, Done: False
# State: [-0.33462772  0.00419441], Reward: -1.0, Done: False
# State: [-0.3327759   0.00185183], Reward: -1.0, Done: False
# State: [-0.33227834  0.00049756], Reward: -1.0, Done: False
# State: [-0.33413818 -0.00185985], Reward: -1.0, Done: False
# State: [-0.3373437  -0.00320552], Reward: -1.0, Done: False
# State: [-0.34187457 -0.00453087], Reward: -1.0, Done: False
# State: [-0.34770185 -0.00582728], Reward: -1.0, Done: False
# State: [-0.355788   -0.00808613], Reward: -1.0, Done: False
# State: [-0.36408022 -0.00829222], Reward: -1.0, Done: False
# State: [-0.37452367 -0.01044346], Reward: -1.0, Done: False
# State: [-0.3860483  -0.01152463], Reward: -1.0, Done: False
# State: [-0.3985755  -0.01252723], Reward: -1.0, Done: False
# State: [-0.41301858 -0.01444307], Reward: -1.0, Done: False
# State: [-0.4272759  -0.01425729], Reward: -1.0, Done: False
# State: [-0.4422456 -0.0149697], Reward: -1.0, Done: False
# State: [-0.45881942 -0.01657381], Reward: -1.0, Done: False
# State: [-0.47487602 -0.0160566 ], Reward: -1.0, Done: False
# State: [-0.49129674 -0.01642073], Reward: -1.0, Done: False
# State: [-0.50895935 -0.01766261], Reward: -1.0, Done: False
# State: [-0.5267317  -0.01777237], Reward: -1.0, Done: False
# State: [-0.5444806  -0.01774888], Reward: -1.0, Done: False
# State: [-0.562073   -0.01759236], Reward: -1.0, Done: False
# State: [-0.5793774  -0.01730445], Reward: -1.0, Done: False
# State: [-0.5962655  -0.01688806], Reward: -1.0, Done: False
# State: [-0.61361283 -0.01734737], Reward: -1.0, Done: False
# State: [-0.63029325 -0.01668043], Reward: -1.0, Done: False
# State: [-0.64618707 -0.01589382], Reward: -1.0, Done: False
# State: [-0.6611821  -0.01499499], Reward: -1.0, Done: False
# State: [-0.6761743  -0.01499217], Reward: -1.0, Done: False
# State: [-0.6900616  -0.01388739], Reward: -1.0, Done: False
# State: [-0.7027518  -0.01269017], Reward: -1.0, Done: False
# State: [-0.7151621  -0.01241028], Reward: -1.0, Done: False
# State: [-0.72621346 -0.01105135], Reward: -1.0, Done: False
# State: [-0.73483706 -0.0086236 ], Reward: -1.0, Done: False
# State: [-0.7409803  -0.00614324], Reward: -1.0, Done: False
# State: [-0.7446063  -0.00362601], Reward: -1.0, Done: False
# State: [-0.7476936  -0.00308726], Reward: -1.0, Done: False
# State: [-0.7502239  -0.00253032], Reward: -1.0, Done: False
# State: [-7.5018245e-01  4.1418309e-05], Reward: -1.0, Done: False
# State: [-7.4956954e-01  6.1291695e-04], Reward: -1.0, Done: False
# State: [-0.7483887   0.00118084], Reward: -1.0, Done: False
# State: [-0.7466469   0.00174185], Reward: -1.0, Done: False
# State: [-0.7423542   0.00429264], Reward: -1.0, Done: False
# State: [-0.7375362   0.00481805], Reward: -1.0, Done: False
# State: [-0.7302215   0.00731467], Reward: -1.0, Done: False
# State: [-0.7204545   0.00976699], Reward: -1.0, Done: False
# State: [-0.70929545  0.01115907], Reward: -1.0, Done: False
# State: [-0.6958146   0.01348086], Reward: -1.0, Done: False
# State: [-0.68009883  0.01571578], Reward: -1.0, Done: False
# State: [-0.66325194  0.01684688], Reward: -1.0, Done: False
# State: [-0.644388    0.01886391], Reward: -1.0, Done: False
# State: [-0.6236379   0.02075013], Reward: -1.0, Done: False
# State: [-0.6031487   0.02048921], Reward: -1.0, Done: False
# State: [-0.5830685   0.02008019], Reward: -1.0, Done: False
# State: [-0.56354463  0.01952385], Reward: -1.0, Done: False
# State: [-0.5437219   0.01982273], Reward: -1.0, Done: False
# State: [-0.5247483   0.01897356], Reward: -1.0, Done: False
# State: [-0.50676614  0.01798218], Reward: -1.0, Done: False
# State: [-0.4899102   0.01685599], Reward: -1.0, Done: False
# State: [-0.47330642  0.01660376], Reward: -1.0, Done: False
# State: [-0.4580784   0.01522799], Reward: -1.0, Done: False
# State: [-0.4433387   0.01473975], Reward: -1.0, Done: False
# State: [-0.42919508  0.0141436 ], Reward: -1.0, Done: False
# State: [-0.41675007  0.012445  ], Reward: -1.0, Done: False
# State: [-0.4040928   0.01265728], Reward: -1.0, Done: False
# State: [-0.39331272  0.01078007], Reward: -1.0, Done: False
# State: [-0.3834851   0.00982761], Reward: -1.0, Done: False
# State: [-0.3746777   0.00880743], Reward: -1.0, Done: False
# State: [-0.36695036  0.00772731], Reward: -1.0, Done: False
# State: [-0.35935515  0.00759522], Reward: -1.0, Done: False
# State: [-0.3539425   0.00541263], Reward: -1.0, Done: False
# State: [-0.3507481   0.00319444], Reward: -1.0, Done: False
# State: [-0.3487927   0.00195538], Reward: -1.0, Done: False
# State: [-0.34708908  0.00170361], Reward: -1.0, Done: False
# State: [-0.3476483  -0.00055921], Reward: -1.0, Done: False
# State: [-0.3484667 -0.0008184], Reward: -1.0, Done: False
# State: [-0.350539   -0.00207229], Reward: -1.0, Done: False
# State: [-0.3538517  -0.00331271], Reward: -1.0, Done: False
# State: [-0.3573832 -0.0035315], Reward: -1.0, Done: False
# State: [-0.3621103  -0.00472709], Reward: -1.0, Done: False
# State: [-0.36800173 -0.00589143], Reward: -1.0, Done: False
# State: [-0.37401822 -0.00601649], Reward: -1.0, Done: False
# State: [-0.3821193  -0.00810107], Reward: -1.0, Done: False
# State: [-0.39024988 -0.00813059], Reward: -1.0, Done: False
# State: [-0.40035412 -0.01010425], Reward: -1.0, Done: False
# State: [-0.4123618  -0.01200766], Reward: -1.0, Done: False
# State: [-0.42518833 -0.01282654], Reward: -1.0, Done: False
# State: [-0.43974227 -0.01455395], Reward: -1.0, Done: False
# State: [-0.45491853 -0.01517626], Reward: -1.0, Done: False
# State: [-0.47160625 -0.01668772], Reward: -1.0, Done: False
# State: [-0.48968235 -0.01807609], Reward: -1.0, Done: False
# State: [-0.50901234 -0.01933002], Reward: -1.0, Done: False
# State: [-0.52745175 -0.01843938], Reward: -1.0, Done: False
# State: [-0.54586226 -0.01841049], Reward: -1.0, Done: False
# State: [-0.56410587 -0.01824364], Reward: -1.0, Done: False
# State: [-0.58204645 -0.01794058], Reward: -1.0, Done: False
# State: [-0.5985509  -0.01650446], Reward: -1.0, Done: False
# State: [-0.61549795 -0.01694705], Reward: -1.0, Done: False
# State: [-0.63276446 -0.0172665 ], Reward: -1.0, Done: False
# State: [-0.6492268  -0.01646232], Reward: -1.0, Done: False
# State: [-0.66376907 -0.01454226], Reward: -1.0, Done: False
# State: [-0.67729074 -0.01352169], Reward: -1.0, Done: False
# State: [-0.6897001  -0.01240941], Reward: -1.0, Done: False
# State: [-0.7019147  -0.01221457], Reward: -1.0, Done: False
# State: [-0.7138548  -0.01194008], Reward: -1.0, Done: False
# State: [-0.72444415 -0.01058938], Reward: -1.0, Done: False
# State: [-0.7346167  -0.01017255], Reward: -1.0, Done: False
# State: [-0.7423102  -0.00769352], Reward: -1.0, Done: False
# State: [-0.7474786  -0.00516838], Reward: -1.0, Done: False
# State: [-0.7520913 -0.0046127], Reward: -1.0, Done: False
# State: [-0.7551214  -0.00303009], Reward: -1.0, Done: False
# State: [-0.7575514  -0.00242996], Reward: -1.0, Done: False
# State: [-7.5736725e-01  1.8413400e-04], Reward: -1.0, Done: False
# State: [-0.75557005  0.00179717], Reward: -1.0, Done: False
# State: [-0.7531702   0.00239989], Reward: -1.0, Done: False
# State: [-0.7481814   0.00498875], Reward: -1.0, Done: False
# State: [-0.7416329   0.00654855], Reward: -1.0, Done: False
# State: [-0.7335632   0.00806967], Reward: -1.0, Done: False
# State: [-0.72302085  0.01054232], Reward: -1.0, Done: False
# State: [-0.71107054  0.01195034], Reward: -1.0, Done: False
# State: [-0.6977871   0.01328342], Reward: -1.0, Done: False
# State: [-0.68425596  0.01353118], Reward: -1.0, Done: False
# State: [-0.6695659  0.01469  ], Reward: -1.0, Done: False
# State: [-0.65381587  0.0157501 ], Reward: -1.0, Done: False
# State: [-0.63611376  0.01770207], Reward: -1.0, Done: False
# State: [-0.61658376  0.01953   ], Reward: -1.0, Done: False
# State: [-0.5973654   0.01921838], Reward: -1.0, Done: False
# State: [-0.57859826  0.01876713], Reward: -1.0, Done: False
# State: [-0.5594205   0.01917775], Reward: -1.0, Done: False
# State: [-0.53997463  0.0194459 ], Reward: -1.0, Done: False
# State: [-0.52140594  0.01856867], Reward: -1.0, Done: False
# State: [-0.5018537   0.01955222], Reward: -1.0, Done: False
# State: [-0.48246446  0.01938925], Reward: -1.0, Done: False
# State: [-0.46438295  0.01808153], Reward: -1.0, Done: False
# State: [-0.4477432   0.01663974], Reward: -1.0, Done: False
# State: [-0.43166748  0.01607572], Reward: -1.0, Done: False
# State: [-0.41727254  0.01439494], Reward: -1.0, Done: False
# State: [-0.4026616   0.01461095], Reward: -1.0, Done: False
# State: [-0.3889379   0.01372369], Reward: -1.0, Done: False
# State: [-0.3751969   0.01374098], Reward: -1.0, Done: False
# State: [-0.36153254  0.01366437], Reward: -1.0, Done: False
# State: [-0.34903634  0.0124962 ], Reward: -1.0, Done: False
# State: [-0.33879033  0.01024601], Reward: -1.0, Done: False
# State: [-0.33086047  0.00792987], Reward: -1.0, Done: False
# State: [-0.3232969   0.00756355], Reward: -1.0, Done: False
# ...
# State: [-1.0940927   0.02290027], Reward: -1.0, Done: False
# State: [-1.0687171   0.02537557], Reward: -1.0, Done: False
# State: [-1.0408468   0.02787036], Reward: -1.0, Done: False
# State: [-1.0104768   0.03036991], Reward: -1.0, Done: False
# State: [-0.9776221   0.03285475], Reward: -1.0, Done: False
# State: [-0.94332165  0.03430049], Reward: -1.0, Done: False
# State: [-0.90564156  0.03768008], Reward: -1.0, Done: False
# State: [-0.8646835   0.04095802], Reward: -1.0, Done: False
# State: [-0.820591    0.04409254], Reward: -1.0, Done: False
# State: [-0.7735542   0.04703675], Reward: -1.0, Done: False
# State: [-0.72481364  0.04874061], Reward: -1.0, Done: False
# State: [-0.6756539   0.04915972], Reward: -1.0, Done: False
# State: [-0.6243929   0.05126099], Reward: -1.0, Done: False
# State: [-0.57338744  0.05100548], Reward: -1.0, Done: False
# State: [-0.5230099   0.05037751], Reward: -1.0, Done: False
# State: [-0.47163683  0.05137309], Reward: -1.0, Done: False
# State: [-0.41965187  0.05198495], Reward: -1.0, Done: False
# State: [-0.36943394  0.05021793], Reward: -1.0, Done: False
# State: [-0.31933147  0.05010247], Reward: -1.0, Done: False
# State: [-0.27166688  0.04766457], Reward: -1.0, Done: False
# State: [-0.22471699  0.0469499 ], Reward: -1.0, Done: False
# State: [-0.17872019  0.04599681], Reward: -1.0, Done: False
# State: [-0.13487257  0.04384762], Reward: -1.0, Done: False
# State: [-0.09332309  0.04154948], Reward: -1.0, Done: False
# State: [-0.05317627  0.04014682], Reward: -1.0, Done: False
# State: [-0.0154977   0.03767857], Reward: -1.0, Done: False
# State: [0.02068357 0.03618127], Reward: -1.0, Done: False
# State: [0.05536965 0.03468608], Reward: -1.0, Done: False
# State: [0.08759014 0.03222049], Reward: -1.0, Done: False
# State: [0.11739644 0.02980631], Reward: -1.0, Done: False
# State: [0.1458562  0.02845976], Reward: -1.0, Done: False
# State: [0.17205149 0.0261953 ], Reward: -1.0, Done: False
# State: [0.19707248 0.02502099], Reward: -1.0, Done: False
# State: [0.22101781 0.02394533], Reward: -1.0, Done: False
# State: [0.24299285 0.02197504], Reward: -1.0, Done: False
# State: [0.26310325 0.0201104 ], Reward: -1.0, Done: False
# State: [0.28045282 0.01734956], Reward: -1.0, Done: False
# State: [0.29513624 0.01468344], Reward: -1.0, Done: False
# State: [0.30923724 0.014101  ], Reward: -1.0, Done: False
# State: [0.32283908 0.01360184], Reward: -1.0, Done: False
# State: [0.3340246  0.01118553], Reward: -1.0, Done: False
# State: [0.34386376 0.00983914], Reward: -1.0, Done: False
# State: [0.35141927 0.00755551], Reward: -1.0, Done: False
# State: [0.3587401  0.00732082], Reward: -1.0, Done: False
# State: [0.36487427 0.00613418], Reward: -1.0, Done: False
# State: [0.36886248 0.00398822], Reward: -1.0, Done: False
# State: [0.3707314  0.00186893], Reward: -1.0, Done: False
# State: [0.3714936 0.0007622], Reward: -1.0, Done: False
# State: [0.3721542  0.00066059], Reward: -1.0, Done: False
# State: [ 0.37171763 -0.00043657], Reward: -1.0, Done: False
# State: [ 0.37118095 -0.00053667], Reward: -1.0, Done: False
# State: [ 0.36854056 -0.00264039], Reward: -1.0, Done: False
# State: [ 0.36477873 -0.00376183], Reward: -1.0, Done: False
# State: [ 0.3608703  -0.00390843], Reward: -1.0, Done: False
# State: [ 0.35478932 -0.00608099], Reward: -1.0, Done: False
# State: [ 0.34749568 -0.00729363], Reward: -1.0, Done: False
# State: [ 0.33794188 -0.00955381], Reward: -1.0, Done: False
# State: [ 0.32806653 -0.00987536], Reward: -1.0, Done: False
# State: [ 0.31580734 -0.01225918], Reward: -1.0, Done: False
# State: [ 0.30108872 -0.01471863], Reward: -1.0, Done: False
# State: [ 0.28382248 -0.01726625], Reward: -1.0, Done: False
# State: [ 0.263909   -0.01991345], Reward: -1.0, Done: False
# State: [ 0.24123903 -0.02266999], Reward: -1.0, Done: False
# State: [ 0.21669567 -0.02454336], Reward: -1.0, Done: False
# State: [ 0.19116221 -0.02553344], Reward: -1.0, Done: False
# State: [ 0.16352874 -0.02763348], Reward: -1.0, Done: False
# State: [ 0.13269012 -0.03083862], Reward: -1.0, Done: False
# State: [ 0.09854697 -0.03414315], Reward: -1.0, Done: False
# State: [ 0.06201229 -0.03653469], Reward: -1.0, Done: False
# State: [ 0.02302074 -0.03899155], Reward: -1.0, Done: False
# State: [-0.01746485 -0.04048559], Reward: -1.0, Done: False
# State: [-0.06144701 -0.04398216], Reward: -1.0, Done: False
# State: [-0.1068868 -0.0454398], Reward: -1.0, Done: False
# State: [-0.15369917 -0.04681237], Reward: -1.0, Done: False
# State: [-0.20375046 -0.05005128], Reward: -1.0, Done: False
# State: [-0.25484908 -0.05109861], Reward: -1.0, Done: False
# State: [-0.3067519  -0.05190285], Reward: -1.0, Done: False
# State: [-0.3611688  -0.05441689], Reward: -1.0, Done: False
# State: [-0.4157563  -0.05458747], Reward: -1.0, Done: False
# State: [-0.47013852 -0.05438225], Reward: -1.0, Done: False
# State: [-0.52592003 -0.05578149], Reward: -1.0, Done: False
# State: [-0.5806841  -0.05476408], Reward: -1.0, Done: False
# State: [-0.63602215 -0.05533803], Reward: -1.0, Done: False
# State: [-0.6895329  -0.05351075], Reward: -1.0, Done: False
# State: [-0.7418499  -0.05231701], Reward: -1.0, Done: False
# State: [-0.7926445 -0.0507946], Reward: -1.0, Done: False
# State: [-0.8426333  -0.04998882], Reward: -1.0, Done: False
# State: [-0.8905783  -0.04794501], Reward: -1.0, Done: False
# State: [-0.93729424 -0.04671593], Reward: -1.0, Done: False
# State: [-0.9816448  -0.04435059], Reward: -1.0, Done: False
# State: [-1.0245436  -0.04289877], Reward: -1.0, Done: False
# State: [-1.0649482  -0.04040454], Reward: -1.0, Done: False
# State: [-1.1028563  -0.03790809], Reward: -1.0, Done: False
# State: [-1.1372991  -0.03444286], Reward: -1.0, Done: False
# State: [-1.1693327  -0.03203363], Reward: -1.0, Done: False
# State: [-1.2  0. ], Reward: -1.0, Done: False
# State: [-1.1987581  0.0012419], Reward: -1.0, Done: False
# State: [-1.1942703  0.0044879], Reward: -1.0, Done: False
# State: [-1.1875217   0.00674848], Reward: -1.0, Done: False
# State: [-1.1774915   0.01003021], Reward: -1.0, Done: False
# State: [-1.1641499   0.01334164], Reward: -1.0, Done: False
# State: [-1.1474606   0.01668934], Reward: -1.0, Done: False
# State: [-1.1293834  0.0180771], Reward: -1.0, Done: False
# State: [-1.109882    0.01950149], Reward: -1.0, Done: False
# State: [-1.0869246   0.02295742], Reward: -1.0, Done: False
# State: [-1.0604849   0.02643968], Reward: -1.0, Done: False
# State: [-1.0315472  0.0289377], Reward: -1.0, Done: False
# State: [-1.0011122   0.03043494], Reward: -1.0, Done: False
# State: [-0.9672011   0.03391109], Reward: -1.0, Done: False
# State: [-0.9308617   0.03633944], Reward: -1.0, Done: False
# State: [-0.89117295  0.03968872], Reward: -1.0, Done: False
# State: [-0.85025316  0.04091982], Reward: -1.0, Done: False
# State: [-0.8062571   0.04399601], Reward: -1.0, Done: False
# State: [-0.7593863   0.04687086], Reward: -1.0, Done: False
# State: [-0.7108908   0.04849544], Reward: -1.0, Done: False
# State: [-0.66006345  0.05082738], Reward: -1.0, Done: False
# State: [-0.60924095  0.05082252], Reward: -1.0, Done: False
# State: [-0.55678314  0.05245779], Reward: -1.0, Done: False
# State: [-0.5030769   0.05370626], Reward: -1.0, Done: False
# State: [-0.44952446  0.05355244], Reward: -1.0, Done: False
# State: [-0.396523    0.05300144], Reward: -1.0, Done: False
# State: [-0.3434517  0.0530713], Reward: -1.0, Done: False
# State: [-0.2906667   0.05278501], Reward: -1.0, Done: False
# State: [-0.23848993  0.05217677], Reward: -1.0, Done: False
# State: [-0.18820013  0.05028981], Reward: -1.0, Done: False
# State: [-0.14102232  0.0471778 ], Reward: -1.0, Done: False
# State: [-0.09512411  0.04589821], Reward: -1.0, Done: False
# State: [-0.05062479  0.04449932], Reward: -1.0, Done: False
# State: [-0.00959669  0.0410281 ], Reward: -1.0, Done: False
# State: [0.02993245 0.03952913], Reward: -1.0, Done: False
# State: [0.06597166 0.03603921], Reward: -1.0, Done: False
# State: [0.10055967 0.03458801], Reward: -1.0, Done: False
# State: [0.13276058 0.03220091], Reward: -1.0, Done: False
# State: [0.16165717 0.02889659], Reward: -1.0, Done: False
# State: [0.18934204 0.02768487], Reward: -1.0, Done: False
# State: [0.2139195  0.02457746], Reward: -1.0, Done: False
# State: [0.23549435 0.02157485], Reward: -1.0, Done: False
# State: [0.2561676  0.02067322], Reward: -1.0, Done: False
# State: [0.2740434  0.01787584], Reward: -1.0, Done: False
# State: [0.28921762 0.01517419], Reward: -1.0, Done: False
# State: [0.30377525 0.01455764], Reward: -1.0, Done: False
# State: [0.31580114 0.0120259 ], Reward: -1.0, Done: False
# State: [0.32736757 0.01156641], Reward: -1.0, Done: False
# State: [0.3385458  0.01117823], Reward: -1.0, Done: False
# State: [0.3484063  0.00986053], Reward: -1.0, Done: False
# State: [0.35601255 0.00760625], Reward: -1.0, Done: False
# State: [0.3634142  0.00740164], Reward: -1.0, Done: False
# State: [0.36966017 0.00624596], Reward: -1.0, Done: False
# State: [0.37579218 0.00613202], Reward: -1.0, Done: False
# State: [0.38185164 0.00605945], Reward: -1.0, Done: False
# State: [0.38587973 0.0040281 ], Reward: -1.0, Done: False
# State: [0.38790408 0.00202434], Reward: -1.0, Done: False
# State: [0.38993856 0.0020345 ], Reward: -1.0, Done: False
# State: [0.39099726 0.0010587 ], Reward: -1.0, Done: False
# State: [3.9108747e-01 9.0213245e-05], Reward: -1.0, Done: False
# State: [3.9120984e-01 1.2234898e-04], Reward: -1.0, Done: False
# State: [ 0.38936517 -0.00184467], Reward: -1.0, Done: False
# State: [ 0.38754073 -0.00182443], Reward: -1.0, Done: False
# State: [ 0.38472396 -0.00281677], Reward: -1.0, Done: False
# State: [ 0.3818955  -0.00282846], Reward: -1.0, Done: False
# State: [ 0.377036   -0.00485951], Reward: -1.0, Done: False
# State: [ 0.37011236 -0.00692365], Reward: -1.0, Done: False
# State: [ 0.36307782 -0.00703455], Reward: -1.0, Done: False
# State: [ 0.35488534 -0.00819246], Reward: -1.0, Done: False
# State: [ 0.34548086 -0.00940447], Reward: -1.0, Done: False
# State: [ 0.33380318 -0.01167769], Reward: -1.0, Done: False
# State: [ 0.3197777  -0.01402548], Reward: -1.0, Done: False
# State: [ 0.30531707 -0.01446064], Reward: -1.0, Done: False
# State: [ 0.28933382 -0.01598323], Reward: -1.0, Done: False
# State: [ 0.2727347  -0.01659911], Reward: -1.0, Done: False
# State: [ 0.25342676 -0.01930795], Reward: -1.0, Done: False
# State: [ 0.23230721 -0.02111956], Reward: -1.0, Done: False
# State: [ 0.2092706  -0.02303661], Reward: -1.0, Done: False
# State: [ 0.1842107 -0.0250599], Reward: -1.0, Done: False
# State: [ 0.15602294 -0.02818776], Reward: -1.0, Done: False
# State: [ 0.12660408 -0.02941886], Reward: -1.0, Done: False
# State: [ 0.09486338 -0.0317407 ], Reward: -1.0, Done: False
# State: [ 0.06172324 -0.03314014], Reward: -1.0, Done: False
# State: [ 0.02612583 -0.0355974 ], Reward: -1.0, Done: False
# State: [-0.0109639  -0.03708973], Reward: -1.0, Done: False
# State: [-0.05055228 -0.03958838], Reward: -1.0, Done: False
# State: [-0.09161196 -0.04105968], Reward: -1.0, Done: False
# State: [-0.1360778  -0.04446586], Reward: -1.0, Done: False
# State: [-0.18383823 -0.04776042], Reward: -1.0, Done: False
# State: [-0.23372798 -0.04988975], Reward: -1.0, Done: False
# State: [-0.2855279  -0.05179994], Reward: -1.0, Done: False
# State: [-0.33896542 -0.0534375 ], Reward: -1.0, Done: False
# State: [-0.39371794 -0.05475252], Reward: -1.0, Done: False
# State: [-0.4494201  -0.05570216], Reward: -1.0, Done: False
# State: [-0.504674   -0.05525392], Reward: -1.0, Done: False
# State: [-0.5610698  -0.05639578], Reward: -1.0, Done: False
# State: [-0.6171852  -0.05611534], Reward: -1.0, Done: False
# State: [-0.6726078  -0.05542263], Reward: -1.0, Done: False
# State: [-0.7259497  -0.05334191], Reward: -1.0, Done: False
# State: [-0.7768655  -0.05091579], Reward: -1.0, Done: False
# State: [-0.82605934 -0.04919385], Reward: -1.0, Done: False
# State: [-0.87228346 -0.04622411], Reward: -1.0, Done: False
# State: [-0.91534394 -0.04306048], Reward: -1.0, Done: False
# State: [-0.9570975  -0.04175353], Reward: -1.0, Done: False
# State: [-0.99544173 -0.0383443 ], Reward: -1.0, Done: False
# State: [-1.0323161  -0.03687438], Reward: -1.0, Done: False
# State: [-1.066693   -0.03437687], Reward: -1.0, Done: False
# State: [-1.0995741  -0.03288114], Reward: -1.0, Done: False
# State: [-1.1289861  -0.02941194], Reward: -1.0, Done: False
# State: [-1.1559728  -0.02698682], Reward: -1.0, Done: False
# State: [-1.1795917  -0.02361875], Reward: -1.0, Done: False
# State: [-1.2  0. ], Reward: -1.0, Done: False
# State: [-1.1977581  0.0022419], Reward: -1.0, Done: False
# State: [-1.1932669   0.00449118], Reward: -1.0, Done: False
# State: [-1.186512    0.00675497], Reward: -1.0, Done: False
# State: [-1.1784722   0.00803978], Reward: -1.0, Done: False
# State: [-1.1681237  0.0103484], Reward: -1.0, Done: False
# State: [-1.1564381   0.01168569], Reward: -1.0, Done: False
# State: [-1.1423855   0.01405263], Reward: -1.0, Done: False
# State: [-1.1249341   0.01745139], Reward: -1.0, Done: False
# State: [-1.1060504   0.01888371], Reward: -1.0, Done: False
# State: [-1.0837055   0.02234485], Reward: -1.0, Done: False
# State: [-1.0578756   0.02582987], Reward: -1.0, Done: False
# State: [-1.0295471   0.02832859], Reward: -1.0, Done: False
# State: [-0.99972194  0.02982508], Reward: -1.0, Done: False
# State: [-0.9664222   0.03329977], Reward: -1.0, Done: False
# State: [-0.93169546  0.03472672], Reward: -1.0, Done: False
# State: [-0.89361733  0.03807814], Reward: -1.0, Done: False
# State: [-0.85229987  0.04131745], Reward: -1.0, Done: False
# State: [-0.80889773  0.04340215], Reward: -1.0, Done: False
# State: [-0.7626077   0.04629005], Reward: -1.0, Done: False
# State: [-0.7136748   0.04893291], Reward: -1.0, Done: False
# State: [-0.6633923   0.05028247], Reward: -1.0, Done: False
# State: [-0.61209184  0.05130046], Reward: -1.0, Done: False
# State: [-0.5601354   0.05195639], Reward: -1.0, Done: False
# State: [-0.5079056   0.05222987], Reward: -1.0, Done: False
# State: [-0.45679337  0.05111221], Reward: -1.0, Done: False
# State: [-0.40517884  0.05161452], Reward: -1.0, Done: False
# State: [-0.3534339   0.05174493], Reward: -1.0, Done: False
# State: [-0.3019105   0.05152341], Reward: -1.0, Done: False
# State: [-0.25092986  0.05098063], Reward: -1.0, Done: False
# State: [-0.20077369  0.05015618], Reward: -1.0, Done: False
# State: [-0.15167758  0.04909612], Reward: -1.0, Done: False
# State: [-0.10382707  0.0478505 ], Reward: -1.0, Done: False
# State: [-0.05935627  0.0444708 ], Reward: -1.0, Done: False
# State: [-0.01834594  0.04101033], Reward: -1.0, Done: False
# State: [0.02016817 0.03851411], Reward: -1.0, Done: False
# State: [0.05518686 0.03501869], Reward: -1.0, Done: False
# State: [0.08673974 0.03155287], Reward: -1.0, Done: False
# State: [0.11587678 0.02913704], Reward: -1.0, Done: False
# State: [0.14366336 0.02778658], Reward: -1.0, Done: False
# State: [0.16917858 0.0255152 ], Reward: -1.0, Done: False
# State: [0.1925089  0.02333034], Reward: -1.0, Done: False
# State: [0.21474472 0.0222358 ], Reward: -1.0, Done: False
# State: [0.23598161 0.0212369 ], Reward: -1.0, Done: False
# State: [0.25631925 0.02033765], Reward: -1.0, Done: False
# State: [0.27586034 0.01954106], Reward: -1.0, Done: False
# State: [0.29370975 0.01784942], Reward: -1.0, Done: False
# State: [0.31096846 0.01725871], Reward: -1.0, Done: False
# State: [0.32773843 0.01676996], Reward: -1.0, Done: False
# State: [0.3441225  0.01638409], Reward: -1.0, Done: False
# State: [0.35922462 0.01510212], Reward: -1.0, Done: False
# State: [0.3731433  0.01391867], Reward: -1.0, Done: False
# State: [0.38697147 0.01382818], Reward: -1.0, Done: False
# State: [0.40080342 0.01383193], Reward: -1.0, Done: False
# State: [0.41273504 0.01193165], Reward: -1.0, Done: False
# State: [0.42385048 0.01111542], Reward: -1.0, Done: False
# State: [0.43522888 0.01137842], Reward: -1.0, Done: False
# State: [0.44695228 0.01172339], Reward: -1.0, Done: False
# State: [0.45810586 0.01115359], Reward: -1.0, Done: False
# State: [0.46977141 0.01166555], Reward: -1.0, Done: False
# State: [0.481035   0.01126359], Reward: -1.0, Done: False
# State: [0.49198022 0.01094523], Reward: -1.0, Done: False
# State: [0.50168866 0.00970845], Reward: -1.0, Done: True

# %% [markdown]
# ## Part II (6 points)
#
# In this part, you will practice writing code for approximating the state value function.
#
# (a) write a function that generates Fourier basis features for a problem with one continuous state (1D state). The output of this function should be a vector of Fourier basis functions,
# $X(s) = [\cos(0 * \pi * s), ..., \cos(n * \pi * s)]$ where $n$ represents the approximation order.
#
# (b) Write a function that given a state $S$ and a weight vector $w$ calculates $V(S, w)$ by multiplying $w$ and $X(S)$. Make sure this is a vector-vector multiplication and avoid using for loops. Test your function with different values of $w$ and $S$.
#
# (c) Does $S$ need to be bounded? If yes, how would you do that?

# %%
# # part II.a --- Your code here ---


def fourier_basis(state, order):
    # Ensure that state is a numeric value
    if not isinstance(state, (int, float)):
        raise ValueError("State must be a numeric value.")
    
    # Compute basis features
    basis_features = [np.cos(i * np.pi * state) for i in range(order + 1)]
    
    return np.array(basis_features)



# def fourier_basis(state, approximation_order):
#     """
#     Function to generate Fourier basis features for 1D state.
    
#     Parameters:
#     - state: The 1D state for which Fourier basis features are generated.
#     - approximation_order: The order of approximation (number of basis functions).

#     Returns:
#     - basis_features: A numpy array of Fourier basis features.
#     """
#     basis_features = []
#     for i in range(approximation_order + 1):
#         basis_features.append(np.cos(i * np.pi * state))
#     return np.array(basis_features)

# %%
# # part II.b --- Your code here ---

def calculate_state_value(state, weights):
    """
    Function to calculate state value using weight vector.

    Parameters:
    - state: The current state for which the value is calculated.
    - weights: The weight vector used for approximation.

    Returns:
    - state_value: The estimated state value.
    """
    if isinstance(state, (list, np.ndarray)):
        # Process state as a sequence
        basis_features = [np.cos(i * np.pi * s) for s in state]
    else:
        # Process state as a numeric value
        basis_features = fourier_basis(state, len(weights) - 1)
    
    state_value = np.dot(basis_features, weights)
    return state_value






# def state_value_approximation(state, weights):
#     # Assuming state is a scalar
#     features = fourier_basis_features(state, len(weights)-1)
#     value = np.dot(features, weights)
#     return value

# %% [markdown]
# # Part II.c
#
# Answer: Stress increasingly becomes one of the major problems of our time, so it needs deep analysis today. Although a lot of headway has been made with regard to understanding psychological factors and developing psychotherapies, stress is still an encompassing problem. However, this problem becomes more severe with the complex nature of current life that leads to stress-related conditions in a broad range. Thus, the problem statement aims to unravel the complex associations between stress and its psychological consequences.

# %% [markdown]
# ## Part III (40 points)
#
# Implement the **Episodic Semi-gradient SARSA** (pp. 244).

# %%
class SARSAAgent:
    def __init__(self, env, approximation_order, alpha, gamma, epsilon, num_episodes):
        self.env = env
        self.approximation_order = approximation_order
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.num_episodes = num_episodes
        self.weights = np.zeros((approximation_order + 1, approximation_order + 1, env.action_space.n))
        self.episode_rewards = []
        
    def policy(self, state):
        # Check if state is a NumPy array and has exactly two elements
        if isinstance(state, np.ndarray) and state.shape == (2,):
            state1, state2 = state
            state1 = float(state1)
            state2 = float(state2)
        elif isinstance(state, tuple):
            state1, state2 = state
            state1 = float(state1)
            state2 = float(state2)
        else:
            raise ValueError("State format is not recognized.")

        # Now state1 and state2 are properly formatted
        # Calculate the value for each action and return the action with the highest value
        values = [calculate_state_value((state1, state2), self.weights[:, :, a]) for a in range(self.env.action_space.n)]
        return np.argmax(values) if np.random.rand() > self.epsilon else self.env.action_space.sample()
    

    def learn(self):
        for episode in range(self.num_episodes):
            state = self.env.reset()
            episode_reward = 0
            while True:
                action = self.policy(state)
                next_state, reward, done, _ = self.env.step(action)
                episode_reward += reward

                # Calculate TD error
                td_error = reward + self.gamma * calculate_state_value(next_state, self.weights[:, :, action]) \
                           - calculate_state_value(state, self.weights[:, :, action])

                # Update weights using gradient descent
                basis_features = fourier_basis(state, self.approximation_order)
                self.weights[:, :, action] += self.alpha * td_error * basis_features

                state = next_state
                if done:
                    break
            self.episode_rewards.append(episode_reward)

# %% [markdown]
# ## Part IV (50 points)
#
# (a) Use the algorithm to learn the Mountain Car task. Tune the step-size parameter ($\alpha$), select a proper Function Approximation order, discount factor ($\gamma$), exploration probability ($\varepsilon$).
#
#
# (b) Plot sum of reward-per-episode vs. number of episodes. This plot should be averaged over 50-100 runs.
#
#
# (c) Plot step-per-episode (in log scale) vs. number of episodes. This plot should be averaged over 50-100 runs.
#
# (d) Animate the last episode in a selected run. Does the approximated policy seem optimal? Why?

# %%
# Corrected Part IV: Learn Mountain Car Task with SARSA
approximation_order = 5
alpha = 0.01
gamma = 0.99
epsilon = 0.1
num_episodes = 1000
num_runs = 50

avg_rewards = np.zeros(num_episodes)
for run in range(num_runs):
    agent = SARSAAgent(env, approximation_order, alpha, gamma, epsilon, num_episodes)
    agent.learn()
    avg_rewards += agent.episode_rewards

avg_rewards /= num_runs

# b) Plot sum of reward-per-episode vs. number of episodes
plt.figure(figsize=(10, 6))
plt.plot(avg_rewards)
plt.xlabel('Episodes')
plt.ylabel('Average Reward per Episode')
plt.title('Average Reward per Episode vs. Episodes')
plt.grid(True)
plt.show()

# c) Plot step-per-episode (in log scale) vs. number of episodes
steps_per_episode = np.array([len(agent.episode_rewards[i]) for i in range(num_episodes)])
plt.figure(figsize=(10, 6))
plt.semilogy(range(num_episodes), steps_per_episode)
plt.xlabel('Episodes')
plt.ylabel('Steps per Episode (log scale)')
plt.title('Steps per Episode (log scale) vs. Episodes')
plt.grid(True)
plt.show()

# d) Animate the last episode in a selected run
selected_run = 0  # Change this to select a specific run
agent = SARSAAgent(env, approximation_order, alpha, gamma, epsilon, num_episodes)
agent.learn()
state = env.reset()
for _ in range(len(agent.episode_rewards[selected_run])):
    action = agent.policy(state)
    state, _, done, _ = env.step(action)
    env.render()
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\admin\Downloads\New_folder\Python\jupiter_notebooks\Notebooks\reinforce_learning.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> for run in range(num_runs):
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>     agent = SARSAAgent(env, approximation_order, alpha, gamma, epsilon, num_episodes)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a>     agent.learn()
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a>     avg_rewards += agent.episode_rewards
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> avg_rewards /= num_runs
#
# c:\Users\admin\Downloads\New_folder\Python\jupiter_notebooks\Notebooks\reinforce_learning.ipynb Cell 16 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=33'>34</a> episode_reward = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=34'>35</a> while True:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=35'>36</a>     action = self.policy(state)
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=36'>37</a>     next_state, reward, done, _ = self.env.step(action)
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=37'>38</a>     episode_reward += reward
#
# c:\Users\admin\Downloads\New_folder\Python\jupiter_notebooks\Notebooks\reinforce_learning.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=17'>18</a> elif isinstance(state, tuple):
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=18'>19</a>     state1, state2 = state
# ---> <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a>     state1 = float(state1)
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a>     state2 = float(state2)
#      <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/New_folder/Python/jupiter_notebooks/Notebooks/reinforce_learning.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a> else:
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# ## Part V (Extra Points)
#
# (a) Implement the **Episodic Semi-gradient $n$-step SARSA** (pp. 247).

# %%
class nStepSARSAAgent:
    def __init__(self, env, approximation_order, alpha, gamma, epsilon, num_episodes, n):
        self.env = env
        self.approximation_order = approximation_order
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.num_episodes = num_episodes
        self.n = n
        self.weights = np.zeros((approximation_order + 1, env.action_space.n))
        self.episode_rewards = []

    def policy(self, state):
        if np.random.rand() < self.epsilon:
            return self.env.action_space.sample()
        else:
            values = [calculate_state_value(state, self.weights[:, a]) for a in range(self.env.action_space.n)]
            return np.argmax(values)

    def learn(self):
        for episode in range(self.num_episodes):
            state = self.env.reset()
            episode_reward = 0
            done = False
            trajectory = []

            while not done:
                action = self.policy(state)
                next_state, reward, done, _ = self.env.step(action)
                episode_reward += reward
                trajectory.append((state, action, reward))

                if len(trajectory) >= self.n:
                    # Calculate n-step return
                    G = 0
                    for i in range(self.n):
                        G += (self.gamma ** i) * trajectory[i][2]

                    if len(trajectory) == self.n:
                        # Add the estimated state value for the next state
                        G += (self.gamma ** self.n) * calculate_state_value(next_state, self.weights[:, action])

                    # Calculate TD error and update weights
                    update_state, update_action, update_reward = trajectory.pop(0)
                    td_error = G - calculate_state_value(update_state, self.weights[:, update_action])
                    basis_features = fourier_basis(update_state, self.approximation_order)
                    self.weights[:, update_action] += self.alpha * td_error * basis_features

                state = next_state

            self.episode_rewards.append(episode_reward)

# %% [markdown]
# (b) Use the algorithm to learn the Mountain Car task with $n \in \{1, 8, 16\}$. Tune the step-size parameter ($\alpha$), select a proper Function Approximation order, discount factor ($\gamma$), exploration probability ($\varepsilon$). Plot step-per-episode (in log scale) vs. number of episodes. This plot should be averaged over 50-100 runs.

# %%
# Your code here
env = gym.make('MountainCar-v0')
approximation_order = 5
alpha = 0.01
gamma = 0.99
epsilon = 0.1
num_episodes = 1000
num_runs = 50
n = 5

avg_rewards = np.zeros(num_episodes)
for run in range(num_runs):
    agent = nStepSARSAAgent(env, approximation_order, alpha, gamma, epsilon, num_episodes, n)
    agent.learn()
    avg_rewards += np.array(agent.episode_rewards)

avg_rewards /= num_runs

# %% [markdown]
# (c) Show an animation of the task for each $n$.

# %%
# Your code here

def animate_episode(agent, n, selected_run):
    state = env.reset()
    done = False
    frames = []
    while not done:
        frames.append(env.render(mode='rgb_array'))
        action = agent.policy(state)
        state, _, done, _ = env.step(action)
    return frames

# Select a run for animation
selected_run = 0
frames = animate_episode(agent, n, selected_run)

# Display animation
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

fig, ax = plt.subplots()
patch = ax.imshow(frames[0])
ax.axis('off')

def animate(i):
    patch.set_data(frames[i])

ani = animation.FuncAnimation(fig, animate, frames=len(frames), interval=50)
HTML(ani.to_jshtml())

# %% [markdown]
# (d) Which value of $n$ results in faster learning? Why?

# %% [markdown]
# >Answer

# %%
n_values = [1, 5, 10, 20]
avg_rewards_by_n = []

for n in n_values:
    avg_rewards = np.zeros(num_episodes)
    for run in range(num_runs):
        agent = nStepSARSAAgent(env, approximation_order, alpha, gamma, epsilon, num_episodes, n)
        agent.learn()
        avg_rewards += np.array(agent.episode_rewards)
    avg_rewards /= num_runs
    avg_rewards_by_n.append(avg_rewards)

# Plotting average rewards for different n values
plt.figure(figsize=(10, 6))
for i, n in enumerate(n_values):
    plt.plot(avg_rewards_by_n[i], label=f'n = {n}')
plt.xlabel('Episodes')
plt.ylabel('Average Reward per Episode')
plt.title('Average Reward per Episode vs. Episodes (Different n values)')
plt.legend()
plt.grid(True)
plt.show()
